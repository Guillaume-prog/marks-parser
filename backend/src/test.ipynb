# %%
import tabula

# %%
data = tabula.read_pdf("../res/mark-sheets/1A_SRI_2021_22__NOTES_ELUMC5A1_Langues(Anglais)_N.SCICLUNA_Etudiants.pdf", pages=1)[0]
data
# Out:
# Got stderr: Jul 31, 2022 9:26:32 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif' for 'TimesNewRomanPSMT'
# Jul 31, 2022 9:26:33 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'TimesNewRomanPS-BoldMT'
# Jul 31, 2022 9:26:34 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif' for 'TimesNewRomanPSMT'
# Jul 31, 2022 9:26:34 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'TimesNewRomanPS-BoldMT'
#                                                S.R.I.
# 0                       1e année d'école d'ingénieurs
# 1                          2021 - 22 Pour information
# 2                                 Version FINALE : V4
# 3   EVALUATION :  ELUMC5A1 - Langues (LV1 - Anglai...
# 4                                          oral écrit
# ...

# %%
metadata = data.loc[3]
sp = metadata[0].split(" ")

code = sp[3]
name = " ".join(sp[5:-1])

code, name
# Out:
# ('ELUMC5A1', 'Langues (LV1 - Anglais) - N. CC1')

# %%
def split_col(col: str):
    sp = col.split(" ")
    return sp[0], " ".join(sp[1:])

cols = data.loc[6:]
marks = [ split_col(x) for x in cols["S.R.I."]]

# %%
res = filter(lambda x: x[0] == "22108939", marks)
code, name, next(res, None)[1]
# Out:
# ('ELUMC5A1', 'Langues (LV1 - Anglais) - N. CC1', '16,5 17 16')
